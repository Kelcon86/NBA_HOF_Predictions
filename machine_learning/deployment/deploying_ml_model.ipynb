# %% [markdown]
# ### Machine Learning Deployment

# %%
# imports
import psycopg2
import pandas as pd
import numpy as np
import pickle
from sqlalchemy import create_engine

import config as c

# import for multiple output per cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Load data from database

# %%
# connection to database
connection = psycopg2.connect(
    host = c.host,
    port = c.port,
    user = c.user,
    password = c.password,
    database = c.database
    )
cursor=connection.cursor()

# %%
data_sql = """
SELECT *
FROM comprehensive_dataset;
"""

#  load in tables as dataframes
data_df = pd.read_sql(data_sql, con=connection)
data_df.head()
# Out:
#                  GUID             Name HallOfFameStatus  HallofFameClass  \
# 0       MIKENILES1980       Mike Niles     Not Inducted              NaN
# 1  JAREDSULLINGER2012  Jared Sullinger     Not Inducted              NaN
# 2  ARNETTMOULTRIE2012  Arnett Moultrie     Not Inducted              NaN
# 3   PERRYJONESIII2012  Perry Jones III     Not Inducted              NaN
# 4     FESTUSEZELI2012     Festus Ezeli     Not Inducted              NaN
#
#    YearDrafted  TO_YEAR  Years_Played  HOF_Elgibility_Year  Pick  Team  ...  \
# 0         1980     1980             1                 1985   NaN  None  ...
# 1         2012     2016             5                 2021  21.0   BOS  ...
# 2         2012     2013             2                 2018  27.0   MIA  ...
# 3         2012     2014             3                 2019   NaN  None  ...
# 4         2012     2016             5                 2021  30.0   GSW  ...
#
#   OREB  DREB  REB  AST  STL  BLK  TOV   EFF  AGE_ROOKIE_SEASON  numberRound
# 0  0.6   0.7  1.3  0.3  0.2  0.0  0.6   1.4                NaN          NaN
# 1  2.0   3.8  5.9  0.8  0.5  0.5  0.6  10.1               20.0          1.0
# 2  1.6   1.5  3.1  0.2  0.4  0.2  0.4   5.8               21.0          1.0
# 3  0.3   1.3  1.6  0.3  0.1  0.2  0.4   2.4               21.0          1.0
# 4  1.8   2.2  4.0  0.3  0.3  0.9  0.8   5.5               22.0          1.0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Input Prep

# %%
# drop features
data_df.drop(['GUID', 'Name', 'HallOfFameStatus', 'Team', 'College', # dropping object columns  
              
              'HallofFameClass', 'YearDrafted', 'TO_YEAR', 'Years_Played', 
              'HOF_Elgibility_Year', 'GP', 'MIN', 'AGE_ROOKIE_SEASON' # non performance stats
                ], axis=1, inplace=True)

# fill NaNs with 0
data_df = data_df.fillna(0)

data_df.head()
print(data_df.shape)
# Out:
#    Pick  PTS  FGM  FGA   FG%  3P_Made  3PA   3P%  FTM  FTA   FT%  OREB  DREB  \
# 0   0.0  2.6  1.1  3.1  34.8      0.0  0.1  50.0  0.4  0.8  45.9   0.6   0.7
# 1  21.0  6.0  2.5  5.0  49.3      0.0  0.1  20.0  1.0  1.4  74.6   2.0   3.8
# 2  27.0  3.7  1.7  2.9  58.2      0.0  0.0   0.0  0.4  0.6  64.3   1.6   1.5
# 3   0.0  2.3  1.0  2.6  39.4      0.0  0.1   0.0  0.3  0.4  66.7   0.3   1.3
# 4  30.0  2.4  0.9  2.2  43.8      0.0  0.0   0.0  0.6  1.0  53.1   1.8   2.2
#
#    REB  AST  STL  BLK  TOV   EFF  numberRound
# 0  1.3  0.3  0.2  0.0  0.6   1.4          0.0
# 1  5.9  0.8  0.5  0.5  0.6  10.1          1.0
# 2  3.1  0.2  0.4  0.2  0.4   5.8          1.0
# 3  1.6  0.3  0.1  0.2  0.4   2.4          1.0
# 4  4.0  0.3  0.3  0.9  0.8   5.5          1.0
# (1217, 20)

# %% [markdown]
# ## Deploy Model

# %%
# open file and load model
with open('ml_model.sav', 'rb') as machine_learning:
    model = pickle.load(machine_learning)

# %%
# generate predictions on ml_input_df
predictions = model.predict(ml_input_df)
ml_output = np.array(predictions)

# %%
data_df['ML_Prediction'] = ml_output.tolist()
data_df.head()
# Out:
#                 GUID            Name HallOfFameStatus  HallofFameClass  \
# 0      MIKENILES1980      Mike Niles     Not Inducted              NaN
# 1  WAYNEROBINSON1980  Wayne Robinson     Not Inducted              NaN
# 2      BILLYREID1980      Billy Reid     Not Inducted              NaN
# 3    ALEXBRADLEY1981    Alex Bradley     Not Inducted              NaN
# 4     GARRYWITTS1981     Garry Witts     Not Inducted              NaN
#
#    YearDrafted  TO_YEAR  Years_Played  HOF_Elgibility_Year   Pick  Team  ...  \
# 0         1980     1980             1                 1985    NaN  None  ...
# 1         1980     1980             1                 1985   31.0   LAL  ...
# 2         1980     1980             1                 1985  182.0   GSW  ...
# 3         1981     1981             1                 1986   86.0   NYK  ...
# 4         1981     1981             1                 1986  103.0   WSB  ...
#
#     FT%  OREB  DREB  REB  AST  STL  BLK  TOV  EFF  ML_Prediction
# 0  45.9   0.6   0.7  1.3  0.3  0.2  0.0  0.6  1.4              0
# 1  72.9   1.4   2.2  3.6  1.4  0.6  0.3  1.8  7.8              0
# 2  56.4   0.5   0.6  1.0  1.2  0.6  0.1  1.3  2.8              0
# 3  60.4   0.8   0.9  1.7  0.3  0.3  0.1  0.7  3.4              0
# 4  82.5   0.6   0.7  1.3  0.8  0.4  0.1  0.8  3.8              0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Write to Databse as a Table

# %%
# create engine to connect to db
engine = create_engine('postgresql+psycopg2://postgres:tC1sfkNBaUqSH4noRcz6@nba-hof-project.cxpeww6dbftb.us-east-2.rds.amazonaws.com:5432/postgres')

# load df into db
data_df.to_sql('HOF_Predictions', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11884/122541331.py in <module>
#       3
#       4 # load df into db
# ----> 5 data_df.to_sql('HOF_Predictions', engine)
#
# ~\Bootcamp_Progams\Anaconda3_\envs\mlenv\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\Bootcamp_Progams\Anaconda3_\envs\mlenv\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\Bootcamp_Progams\Anaconda3_\envs\mlenv\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1756             index_label=index_label,
#    1757             schema=schema,
# -> 1758             dtype=dtype,
#    1759         )
#    1760
#
# ~\Bootcamp_Progams\Anaconda3_\envs\mlenv\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# ~\Bootcamp_Progams\Anaconda3_\envs\mlenv\lib\site-packages\pandas\io\sql.py in create(self)
#     856         if self.exists():
#     857             if self.if_exists == "fail":
# --> 858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'HOF_Predictions' already exists.
