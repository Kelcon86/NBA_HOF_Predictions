# %%
# Initial imports
import pandas as pd
import numpy as np

# %%
# Load the nba_hof_rookies dataset.
file_path = "../SourceData/nba_hof_rookies.csv"
rookies_df = pd.read_csv(file_path)
rookies_df.head()
# Out:
#            Name  Hall of Fame Class  Year Drafted  GP   MIN  PTS  FGM  FGA  \
# 0    A.C. Green                 NaN          1985  82  18.8  6.4  2.5  4.7
# 1  A.J. English                 NaN          1990  70  20.6  8.8  3.6  8.2
# 2    A.J. Price                 NaN          2009  56  15.4  7.3  2.6  6.3
# 3  Aaron Brooks                 NaN          2007  51  11.9  5.2  1.8  4.4
# 4  Aaron Gordon                 NaN          2014  47  17.0  5.2  2.0  4.4
#
#     FG%  3P Made  ...  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  EFF
# 0  53.9      0.0  ...  2.0  61.1   2.0   2.7  4.6  0.7  0.6  0.6  1.2  8.7
# 1  43.9      0.0  ...  2.2  70.7   0.9   1.2  2.1  2.5  0.4  0.2  1.6  7.1
# 2  41.0      1.1  ...  1.3  80.0   0.2   1.4  1.6  1.9  0.6  0.1  1.1  6.4
# 3  41.3      0.7  ...  1.0  85.7   0.3   0.8  1.1  1.7  0.3  0.1  0.9  4.7
# 4  44.7      0.3  ...  1.3  72.1   1.0   2.6  3.6  0.7  0.5  0.5  0.8  6.8
#
# [5 rows x 23 columns]

# %%
# Check datatypes
rookies_df.dtypes
# Out:
# Name                   object
# Hall of Fame Class    float64
# Year Drafted            int64
# GP                      int64
# MIN                   float64
# PTS                   float64
# FGM                   float64
# FGA                   float64
# FG%                   float64
# 3P Made               float64
# 3PA                   float64
# 3P%                    object
# FTM                   float64
# FTA                   float64
# FT%                   float64
# OREB                  float64
# DREB                  float64
# REB                   float64
# AST                   float64
# STL                   float64
# BLK                   float64
# TOV                   float64
# EFF                   float64
# dtype: object

# %%
# Remove Spaces from Column Names
rookies_df.rename(
    columns={"Hall of Fame Class":"HallofFameClass","Year Drafted":"YearDrafted","3P Made":"3P_Made"}
          ,inplace=True)

# %%
# Clean up 3P% Column; Replace '-' with '0'
rookies_df['3P%'] = rookies_df['3P%'].replace({'-':'0'})
rookies_df.dtypes
# Out:
# Name                object
# HallofFameClass    float64
# YearDrafted          int64
# GP                   int64
# MIN                float64
# PTS                float64
# FGM                float64
# FGA                float64
# FG%                float64
# 3P_Made            float64
# 3PA                float64
# 3P%                 object
# FTM                float64
# FTA                float64
# FT%                float64
# OREB               float64
# DREB               float64
# REB                float64
# AST                float64
# STL                float64
# BLK                float64
# TOV                float64
# EFF                float64
# dtype: object

# %%
# Convert 3P% column to Numeric
#df["2nd"] = pd.to_numeric(df["2nd"])
rookies_df['3P%'] = pd.to_numeric(rookies_df['3P%'])
rookies_df.dtypes
# Out:
# Name                object
# HallofFameClass    float64
# YearDrafted          int64
# GP                   int64
# MIN                float64
# PTS                float64
# FGM                float64
# FGA                float64
# FG%                float64
# 3P_Made            float64
# 3PA                float64
# 3P%                float64
# FTM                float64
# FTA                float64
# FT%                float64
# OREB               float64
# DREB               float64
# REB                float64
# AST                float64
# STL                float64
# BLK                float64
# TOV                float64
# EFF                float64
# dtype: object

# %%
# Copy Hall of Fame Class column to preserve induction year and allow for normalization
rookies_df['HallOfFameStatus'] = rookies_df ['HallofFameClass']
rookies_df.head()
# Out:
#            Name  HallofFameClass  YearDrafted  GP   MIN  PTS  FGM  FGA   FG%  \
# 0    A.C. Green              NaN         1985  82  18.8  6.4  2.5  4.7  53.9
# 1  A.J. English              NaN         1990  70  20.6  8.8  3.6  8.2  43.9
# 2    A.J. Price              NaN         2009  56  15.4  7.3  2.6  6.3  41.0
# 3  Aaron Brooks              NaN         2007  51  11.9  5.2  1.8  4.4  41.3
# 4  Aaron Gordon              NaN         2014  47  17.0  5.2  2.0  4.4  44.7
#
#    3P_Made  ...   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  EFF  \
# 0      0.0  ...  61.1   2.0   2.7  4.6  0.7  0.6  0.6  1.2  8.7
# 1      0.0  ...  70.7   0.9   1.2  2.1  2.5  0.4  0.2  1.6  7.1
# 2      1.1  ...  80.0   0.2   1.4  1.6  1.9  0.6  0.1  1.1  6.4
# 3      0.7  ...  85.7   0.3   0.8  1.1  1.7  0.3  0.1  0.9  4.7
# 4      0.3  ...  72.1   1.0   2.6  3.6  0.7  0.5  0.5  0.8  6.8
#
#    HallOfFameStatus
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 24 columns]

# %%
# Normalize Hall of Fame Class Column; Replace 'NaN' with 'Not Inducted'

#replace NaN values in 'points' and 'rebounds' columns with 'none'
#df[['points', 'rebounds']] = df[['points', 'rebounds']].fillna('none')

rookies_df['HallOfFameStatus'] = rookies_df['HallOfFameStatus'].fillna('Not Inducted')

rookies_df['HallOfFameStatus'] = np.where(rookies_df['HallOfFameStatus'] == "Not Inducted", "Not Inducted", "Hall of Fame Member")
rookies_df.head(50)
# Out:
#                  Name  HallofFameClass  YearDrafted  GP   MIN   PTS  FGM  \
# 0          A.C. Green              NaN         1985  82  18.8   6.4  2.5
# 1        A.J. English              NaN         1990  70  20.6   8.8  3.6
# 2          A.J. Price              NaN         2009  56  15.4   7.3  2.6
# 3        Aaron Brooks              NaN         2007  51  11.9   5.2  1.8
# 4        Aaron Gordon              NaN         2014  47  17.0   5.2  2.0
# 5          Aaron Gray              NaN         2007  61  10.0   4.3  1.7
# 6         Aaron McKie              NaN         1994  45  18.4   6.5  2.6
# 7           Acie Earl              NaN         1993  74  15.5   5.5  2.0
# 8            Acie Law              NaN         2007  56  15.4   4.2  1.7
# 9     Adam Harrington              NaN         2002  19   5.8   1.6  0.6
# 10         Adam Keefe              NaN         1992  82  18.9   6.6  2.3
# 11      Adam Morrison              NaN         2006  78  29.8  11.8  4.6
# 12       Adonal Foyle              NaN         1997  55  11.9   3.0  1.3
# 13      Adreian Payne              NaN         2014  32  23.1   6.7  2.8
# 14    Adrian Caldwell              NaN         1989  51   6.5   1.9  0.8
# 15     Adrian Griffin              NaN         1999  72  26.8   6.7  2.4
# 16         Al Horford              NaN         2007  81  31.4  10.1  4.1
# 17       Al Jefferson              NaN         2004  71  14.8   6.7  2.7
# 18        Al Thornton              NaN         2007  79  27.3  12.7  4.7
# 19     Alaa Abdelnaby              NaN         1990  43   6.7   3.1  1.3
# 20      Alan Anderson              NaN         2005  36  15.7   5.8  2.1
# 21     Alan Henderson              NaN         1995  79  17.9   6.4  2.4
# 22        Albert King              NaN         1981  76  22.3  12.1  5.1
# 23         Alec Burks              NaN         2011  59  15.9   7.2  2.6
# 24       Alec Kessler              NaN         1990  78  16.1   6.2  2.6
# 25       Alex Abrines              NaN         2016  27  13.7   5.6  1.9
# 26       Alex Bradley              NaN         1981  39   8.5   3.5  1.4
# 27           Alex Len              NaN         2013  42   8.6   2.0  0.8
# 28  Alexander Johnson              NaN         2006  59  12.8   4.4  1.5
# 29   Alexander Volkov              NaN         1989  72  13.0   5.0  1.9
# 30       Alexey Shved              NaN         2012  77  23.9   8.6  3.1
# 31    Al-Farouq Aminu              NaN         2010  81  17.9   5.6  2.0
# 32  Alfredrick Hughes              NaN         1985  68  12.7   5.2  2.2
# 33      Allan Houston              NaN         1993  79  19.2   8.5  3.4
# 34          Allan Ray              NaN         2006  47  15.1   6.2  2.1
# 35      Allen Iverson           2016.0         1996  76  40.1  23.5  8.2
# 36    Alonzo Mourning           2014.0         1992  78  33.9  21.0  7.3
# 37         Alton Ford              NaN         2001  53   8.5   3.1  1.2
# 38       Alton Lister              NaN         1981  80  14.8   4.5  1.9
# 39    Alvin Robertson              NaN         1984  79  21.3   9.2  3.8
# 40     Alvin Williams              NaN         1997  54  19.8   6.0  2.3
# 41  Amar'e Stoudemire              NaN         2002  82  31.3  13.5  4.8
# 42   Anderson Varejao              NaN         2004  54  16.0   4.9  1.8
# 43   Andrae Patterson              NaN         1998  35   8.1   3.3  1.2
# 44      Andre Barrett              NaN         2004  38  12.7   3.1  1.2
# 45        Andre Brown              NaN         2006  38   7.1   2.4  1.1
# 46     Andre Drummond              NaN         2012  60  20.7   7.9  3.5
# 47     Andre Iguodala              NaN         2004  82  32.8   9.0  3.3
# 48       Andre Miller              NaN         1999  82  25.5  11.1  4.1
# 49     Andre Roberson              NaN         2013  40  10.0   1.9  0.8
#
#      FGA   FG%  3P_Made  ...   FT%  OREB  DREB   REB  AST  STL  BLK  TOV  \
# 0    4.7  53.9      0.0  ...  61.1   2.0   2.7   4.6  0.7  0.6  0.6  1.2
# 1    8.2  43.9      0.0  ...  70.7   0.9   1.2   2.1  2.5  0.4  0.2  1.6
# 2    6.3  41.0      1.1  ...  80.0   0.2   1.4   1.6  1.9  0.6  0.1  1.1
# 3    4.4  41.3      0.7  ...  85.7   0.3   0.8   1.1  1.7  0.3  0.1  0.9
# 4    4.4  44.7      0.3  ...  72.1   1.0   2.6   3.6  0.7  0.5  0.5  0.8
# 5    3.3  50.5      0.0  ...  56.6   1.1   1.6   2.8  0.7  0.3  0.3  0.9
# 6    5.8  44.4      0.2  ...  68.5   0.8   2.1   2.9  2.0  0.8  0.4  0.9
# 7    5.0  40.6      0.0  ...  67.5   1.1   2.2   3.3  0.2  0.3  0.7  1.0
# 8    4.2  40.1      0.1  ...  79.2   0.2   0.8   1.0  2.0  0.5  0.0  1.0
# 9    1.9  29.7      0.3  ...  75.0   0.1   0.4   0.4  0.6  0.1  0.1  0.1
# 10   4.6  50.0      0.0  ...  70.0   2.1   3.2   5.3  1.0  0.7  0.2  1.2
# 11  12.1  37.6      1.1  ...  71.0   0.7   2.3   2.9  2.1  0.4  0.1  1.7
# 12   3.1  40.6      0.0  ...  43.5   1.3   2.0   3.3  0.3  0.2  0.9  0.9
# 13   6.9  41.4      0.0  ...  65.2   1.5   3.6   5.1  0.9  0.6  0.3  1.4
# 14   1.5  55.3      0.0  ...  46.4   0.7   1.4   2.1  0.1  0.2  0.3  0.6
# 15   5.7  42.4      0.2  ...  75.3   1.8   3.4   5.2  2.5  1.6  0.2  1.3
# 16   8.2  49.9      0.0  ...  73.1   3.1   6.6   9.7  1.5  0.7  0.9  1.7
# 17   5.2  52.8      0.0  ...  63.0   1.7   2.7   4.4  0.3  0.3  0.8  0.9
# 18  11.0  42.9      0.5  ...  74.3   1.2   3.3   4.5  1.2  0.6  0.5  1.6
# 19   2.7  47.4      0.0  ...  56.8   0.6   1.4   2.1  0.3  0.1  0.3  0.5
# 20   5.0  41.4      0.7  ...  80.5   0.6   1.3   1.9  0.9  0.3  0.1  0.9
# 21   5.5  44.2      0.0  ...  59.5   2.1   2.4   4.5  0.6  0.6  0.5  1.1
# 22  10.7  48.2      0.0  ...  77.8   1.4   2.7   4.1  1.9  0.8  0.5  2.4
# 23   6.1  42.9      0.3  ...  72.7   1.0   1.3   2.2  0.9  0.5  0.1  0.9
# 24   6.0  42.5      0.0  ...  67.2   1.5   2.8   4.3  0.4  0.2  0.3  1.4
# 25   4.9  37.9      1.3  ...  90.0   0.3   0.9   1.2  0.4  0.4  0.1  0.6
# 26   2.6  52.4      0.0  ...  60.4   0.8   0.9   1.7  0.3  0.3  0.1  0.7
# 27   1.9  42.3      0.0  ...  64.5   0.9   1.4   2.4  0.1  0.1  0.4  0.6
# 28   2.9  53.8      0.0  ...  66.1   0.8   2.2   3.1  0.3  0.4  0.6  0.8
# 29   3.9  48.2      0.2  ...  58.3   0.7   0.9   1.7  1.2  0.5  0.3  0.7
# 30   8.2  37.2      1.1  ...  72.0   0.5   1.7   2.3  3.7  0.7  0.3  1.9
# 31   5.0  39.4      0.6  ...  77.3   0.9   2.4   3.3  0.7  0.7  0.3  1.3
# 32   5.5  40.9      0.0  ...  58.3   0.7   0.9   1.7  0.9  0.4  0.1  0.9
# 33   8.5  40.5      0.4  ...  82.4   0.2   1.3   1.5  1.3  0.4  0.2  1.3
# 34   5.5  38.6      1.0  ...  76.4   0.4   1.1   1.5  0.9  0.4  0.1  0.9
# 35  19.8  41.6      2.0  ...  70.2   1.5   2.6   4.1  7.5  2.1  0.3  4.4
# 36  14.3  51.1      0.0  ...  78.1   3.4   6.9  10.3  1.0  0.3  3.5  3.0
# 37   2.2  51.7      0.0  ...  73.7   0.6   1.4   2.0  0.1  0.1  0.1  0.6
# 38   3.6  51.9      0.0  ...  52.0   1.4   3.5   4.8  1.1  0.2  1.5  1.6
# 39   7.6  49.8      0.1  ...  73.4   1.5   1.9   3.4  3.5  1.6  0.3  2.1
# 40   5.2  44.3      0.2  ...  72.2   0.4   1.1   1.5  1.9  0.7  0.1  1.1
# 41  10.1  47.2      0.0  ...  66.1   3.0   5.7   8.8  1.0  0.8  1.1  2.3
# 42   3.6  51.3      0.0  ...  53.5   2.0   2.7   4.8  0.5  0.8  0.7  0.5
# 43   2.8  44.3      0.0  ...  77.8   0.9   1.0   1.9  0.4  0.5  0.2  0.6
# 44   3.3  36.3      0.4  ...  73.7   0.3   0.8   1.1  1.8  0.5  0.0  0.7
# 45   1.9  56.8      0.0  ...  60.0   0.7   1.3   1.9  0.1  0.2  0.1  0.8
# 46   5.7  60.8      0.0  ...  37.1   2.8   4.8   7.6  0.5  1.0  1.6  0.9
# 47   6.7  49.3      0.6  ...  74.3   1.1   4.6   5.7  3.0  1.7  0.6  1.7
# 48   9.2  44.9      0.1  ...  77.4   1.0   2.4   3.4  5.8  1.0  0.2  2.0
# 49   1.7  48.5      0.1  ...  70.0   0.9   1.5   2.4  0.4  0.5  0.3  0.5
#
#      EFF     HallOfFameStatus
# 0    8.7         Not Inducted
# 1    7.1         Not Inducted
# 2    6.4         Not Inducted
# 3    4.7         Not Inducted
# 4    6.8         Not Inducted
# 5    5.0         Not Inducted
# 6    7.9         Not Inducted
# 7    5.4         Not Inducted
# 8    4.0         Not Inducted
# 9    1.3         Not Inducted
# 10   9.4         Not Inducted
# 11   7.4         Not Inducted
# 12   4.4         Not Inducted
# 13   7.6         Not Inducted
# 14   3.2         Not Inducted
# 15  11.0         Not Inducted
# 16  16.5         Not Inducted
# 17   8.4         Not Inducted
# 18  10.8         Not Inducted
# 19   3.5         Not Inducted
# 20   4.9         Not Inducted
# 21   7.4         Not Inducted
# 22  11.0         Not Inducted
# 23   5.9         Not Inducted
# 24   6.1         Not Inducted
# 25   3.9         Not Inducted
# 26   3.4         Not Inducted
# 27   3.1         Not Inducted
# 28   6.0         Not Inducted
# 29   5.1         Not Inducted
# 30   8.0         Not Inducted
# 31   6.1         Not Inducted
# 32   3.6         Not Inducted
# 33   5.3         Not Inducted
# 34   4.5         Not Inducted
# 35  19.3  Hall of Fame Member
# 36  24.3  Hall of Fame Member
# 37   3.5         Not Inducted
# 38   8.0         Not Inducted
# 39  11.4         Not Inducted
# 40   5.7         Not Inducted
# 41  15.4         Not Inducted
# 42   8.3         Not Inducted
# 43   3.9         Not Inducted
# 44   3.6         Not Inducted
# 45   2.9         Not Inducted
# 46  13.8         Not Inducted
# 47  14.2         Not Inducted
# 48  13.7         Not Inducted
# 49   3.9         Not Inducted
#
# [50 rows x 24 columns]

# %%
# Create Unique Identifier Field - Concatination of Name and Draft Year
# Converted to All Upper Case, All Punctuation and Spaces Stripped
rookies_df['GUID'] = rookies_df['Name'] + rookies_df['YearDrafted'].astype(str)

# Strip out Single Quote/Apostrophe Characters, Commas, and Periods
rookies_df['GUID'] = rookies_df['GUID'].str.replace(r'[^\w\s]+', '')

# Strip out spaces
rookies_df['GUID'].replace('\s+', '', regex=True,inplace=True)


#rookies_df['GUID'] = rookies_df['GUID'].astype(str)
#rookies_df['GUID'].to_string()

#Convert to Upper Case
rookies_df['GUID'] = rookies_df['GUID'].str.upper()

rookies_df.head(100)
# Out:
# C:\Users\18177\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#               Name  HallofFameClass  YearDrafted  GP   MIN  PTS  FGM  FGA  \
# 0       A.C. Green              NaN         1985  82  18.8  6.4  2.5  4.7
# 1     A.J. English              NaN         1990  70  20.6  8.8  3.6  8.2
# 2       A.J. Price              NaN         2009  56  15.4  7.3  2.6  6.3
# 3     Aaron Brooks              NaN         2007  51  11.9  5.2  1.8  4.4
# 4     Aaron Gordon              NaN         2014  47  17.0  5.2  2.0  4.4
# ..             ...              ...          ...  ..   ...  ...  ...  ...
# 95     Austin Daye              NaN         2009  69  13.3  5.1  2.0  4.3
# 96   Austin Rivers              NaN         2012  61  23.2  6.2  2.4  6.4
# 97   Avery Johnson              NaN         1988  43   6.8  1.6  0.7  1.9
# 98  B.J. Armstrong              NaN         1989  81  15.9  5.6  2.3  4.8
# 99      B.J. Tyler              NaN         1994  55  14.7  3.5  1.3  3.4
#
#      FG%  3P_Made  ...  OREB  DREB  REB  AST  STL  BLK  TOV  EFF  \
# 0   53.9      0.0  ...   2.0   2.7  4.6  0.7  0.6  0.6  1.2  8.7
# 1   43.9      0.0  ...   0.9   1.2  2.1  2.5  0.4  0.2  1.6  7.1
# 2   41.0      1.1  ...   0.2   1.4  1.6  1.9  0.6  0.1  1.1  6.4
# 3   41.3      0.7  ...   0.3   0.8  1.1  1.7  0.3  0.1  0.9  4.7
# 4   44.7      0.3  ...   1.0   2.6  3.6  0.7  0.5  0.5  0.8  6.8
# ..   ...      ...  ...   ...   ...  ...  ...  ...  ...  ...  ...
# 95  46.4      0.4  ...   0.5   2.0  2.5  0.5  0.4  0.4  0.7  5.7
# 96  37.2      0.5  ...   0.3   1.5  1.8  2.1  0.4  0.1  1.2  4.6
# 97  34.9      0.0  ...   0.3   0.3  0.6  1.7  0.5  0.1  0.4  2.6
# 98  48.5      0.0  ...   0.2   1.0  1.3  2.5  0.6  0.1  1.0  6.3
# 99  38.1      0.3  ...   0.2   0.9  1.1  3.2  0.7  0.0  1.8  4.4
#
#     HallOfFameStatus              GUID
# 0       Not Inducted       ACGREEN1985
# 1       Not Inducted     AJENGLISH1990
# 2       Not Inducted       AJPRICE2009
# 3       Not Inducted   AARONBROOKS2007
# 4       Not Inducted   AARONGORDON2014
# ..               ...               ...
# 95      Not Inducted    AUSTINDAYE2009
# 96      Not Inducted  AUSTINRIVERS2012
# 97      Not Inducted  AVERYJOHNSON1988
# 98      Not Inducted   BJARMSTRONG1989
# 99      Not Inducted       BJTYLER1994
#
# [100 rows x 25 columns]

# %%
# Set new index and drop existing index
rookies_df.set_index('GUID')
# Out:
#                                      Name  HallofFameClass  YearDrafted  GP  \
# GUID
# ACGREEN1985                    A.C. Green              NaN         1985  82
# AJENGLISH1990                A.J. English              NaN         1990  70
# AJPRICE2009                    A.J. Price              NaN         2009  56
# AARONBROOKS2007              Aaron Brooks              NaN         2007  51
# AARONGORDON2014              Aaron Gordon              NaN         2014  47
# ...                                   ...              ...          ...  ..
# ZARKOCABARKAPA2003        Zarko Cabarkapa              NaN         2003  49
# ZAZAPACHULIA2003            Zaza Pachulia              NaN         2003  59
# ZELJKOREBRACA2001          Zeljko Rebraca              NaN         2001  74
# ZORANPLANINIC2003          Zoran Planinic              NaN         2003  49
# ZYDRUNASILGAUSKAS1997  Zydrunas Ilgauskas              NaN         1997  82
#
#                         MIN   PTS  FGM   FGA   FG%  3P_Made  ...   FT%  OREB  \
# GUID                                                         ...
# ACGREEN1985            18.8   6.4  2.5   4.7  53.9      0.0  ...  61.1   2.0
# AJENGLISH1990          20.6   8.8  3.6   8.2  43.9      0.0  ...  70.7   0.9
# AJPRICE2009            15.4   7.3  2.6   6.3  41.0      1.1  ...  80.0   0.2
# AARONBROOKS2007        11.9   5.2  1.8   4.4  41.3      0.7  ...  85.7   0.3
# AARONGORDON2014        17.0   5.2  2.0   4.4  44.7      0.3  ...  72.1   1.0
# ...                     ...   ...  ...   ...   ...      ...  ...   ...   ...
# ZARKOCABARKAPA2003     11.6   4.1  1.7   4.0  41.1      0.1  ...  66.0   0.5
# ZAZAPACHULIA2003       11.3   3.3  1.2   3.0  38.9      0.0  ...  64.4   1.2
# ZELJKOREBRACA2001      15.9   6.9  2.6   5.1  50.5      0.0  ...  77.1   1.1
# ZORANPLANINIC2003       9.7   3.1  1.1   2.6  41.1      0.2  ...  63.3   0.3
# ZYDRUNASILGAUSKAS1997  29.0  13.9  5.5  10.7  51.8      0.0  ...  76.2   3.4
#
#                        DREB  REB  AST  STL  BLK  TOV   EFF  HallOfFameStatus
# GUID
# ACGREEN1985             2.7  4.6  0.7  0.6  0.6  1.2   8.7      Not Inducted
# AJENGLISH1990           1.2  2.1  2.5  0.4  0.2  1.6   7.1      Not Inducted
# AJPRICE2009             1.4  1.6  1.9  0.6  0.1  1.1   6.4      Not Inducted
# AARONBROOKS2007         0.8  1.1  1.7  0.3  0.1  0.9   4.7      Not Inducted
# AARONGORDON2014         2.6  3.6  0.7  0.5  0.5  0.8   6.8      Not Inducted
# ...                     ...  ...  ...  ...  ...  ...   ...               ...
# ZARKOCABARKAPA2003      1.5  2.0  0.8  0.2  0.3  1.1   3.6      Not Inducted
# ZAZAPACHULIA2003        1.8  2.9  0.2  0.4  0.2  0.6   4.1      Not Inducted
# ZELJKOREBRACA2001       2.8  3.9  0.5  0.4  1.0  1.1   8.6      Not Inducted
# ZORANPLANINIC2003       0.8  1.1  1.4  0.3  0.1  0.7   3.2      Not Inducted
# ZYDRUNASILGAUSKAS1997   5.4  8.8  0.9  0.6  1.6  1.8  18.0      Not Inducted
#
# [1537 rows x 24 columns]

# %%
# Identify incomplete rows
rookies_df.count()
# Out:
# Name                1537
# HallofFameClass       42
# YearDrafted         1537
# GP                  1537
# MIN                 1537
# PTS                 1537
# FGM                 1537
# FGA                 1537
# FG%                 1537
# 3P_Made             1537
# 3PA                 1537
# 3P%                 1537
# FTM                 1537
# FTA                 1537
# FT%                 1537
# OREB                1537
# DREB                1537
# REB                 1537
# AST                 1537
# STL                 1537
# BLK                 1537
# TOV                 1537
# EFF                 1537
# HallOfFameStatus    1537
# GUID                1537
# dtype: int64

# %%
# Check datatypes
rookies_df.dtypes
# Out:
# Name                 object
# HallofFameClass     float64
# YearDrafted           int64
# GP                    int64
# MIN                 float64
# PTS                 float64
# FGM                 float64
# FGA                 float64
# FG%                 float64
# 3P_Made             float64
# 3PA                 float64
# 3P%                 float64
# FTM                 float64
# FTA                 float64
# FT%                 float64
# OREB                float64
# DREB                float64
# REB                 float64
# AST                 float64
# STL                 float64
# BLK                 float64
# TOV                 float64
# EFF                 float64
# HallOfFameStatus     object
# GUID                 object
# dtype: object

# %%
# Export to CSV
#export_path = "Resources/rookies_df.csv"
#rookies_df.to_csv(export_path)

# %%
# import the necessary packages
import psycopg2
from sqlalchemy import create_engine
  
# Create the engine to connect to the database 
engine = create_engine()

# Write data into the table in database
rookies_df.to_sql('new_rookies', engine)
