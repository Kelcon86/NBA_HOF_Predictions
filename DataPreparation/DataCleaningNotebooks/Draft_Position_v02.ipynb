# %%
# Initial imports
import pandas as pd

# %%
# Load the NBA_Full_Draft_1947-2018.csv dataset.
file_path = "../SourceData/NBA_Full_Draft_1947-2018.csv"
full_draft_df = pd.read_csv(file_path)
full_draft_df.head()
# Out:
#    Unnamed: 0 Team            Player                         College  \
# 0           1  PIT  Clifton McNeeley  University of Texas at El Paso
# 1           2  TRH        Glen Selbo         University of Wisconsin
# 2           3  BOS      Bulbs Ehlers               Purdue University
# 3           4  PRO        Walt Dropo       University of Connecticut
# 4           5  NYK        Dick Holub          Long Island University
#
#    Play_Yrs  Games  Year  Pick
# 0       NaN    NaN  1947     1
# 1       1.0   13.0  1947     2
# 2       2.0   99.0  1947     3
# 3       NaN    NaN  1947     4
# 4       1.0   48.0  1947     5

# %%
# Create a new DataFrame that holds only the Player Name, Year, and Pick Columns.
draft_df = full_draft_df[['Player', 'Year', 'Pick','Team','College']].copy()
draft_df.head()
# Out:
#              Player  Year  Pick Team                         College
# 0  Clifton McNeeley  1947     1  PIT  University of Texas at El Paso
# 1        Glen Selbo  1947     2  TRH         University of Wisconsin
# 2      Bulbs Ehlers  1947     3  BOS               Purdue University
# 3        Walt Dropo  1947     4  PRO       University of Connecticut
# 4        Dick Holub  1947     5  NYK          Long Island University

# %%
# Keep only records for players drafted from 1980 forward.
draft_df = draft_df[draft_df['Year'] >= 1980]
draft_df.head(100)
# Out:
#                  Player  Year  Pick Team                    College
# 4545  Joe Barry Carroll  1980     1  GSW          Purdue University
# 4546   Darrell Griffith  1980     2  UTA   University of Louisville
# 4547       Kevin McHale  1980     3  BOS    University of Minnesota
# 4548      Kelvin Ransey  1980     4  CHI      Ohio State University
# 4549          James Ray  1980     5  DEN    Jacksonville University
# ...                 ...   ...   ...  ...                        ...
# 4640      Mike Campbell  1980    96  CHI    Northwestern University
# 4641      James Patrick  1980    97  DEN     Texas State University
# 4642        Aaron Curry  1980    98  NJN     University of Oklahoma
# 4643         Wally Rank  1980    99  SDC  San Jose State University
# 4644         Joe Galvin  1980   100  IND  Illinois State University
#
# [100 rows x 5 columns]

# %%
# Identify incomplete rows
draft_df.count()
# Out:
# Player     3418
# Year       3418
# Pick       3418
# Team       3418
# College    3086
# dtype: int64

# %%
# Check datatypes
draft_df.dtypes
# Out:
# Player     object
# Year        int64
# Pick        int64
# Team       object
# College    object
# dtype: object

# %%
# Convert Player column to String
draft_df['Player'] = draft_df['Player'].astype(str)
draft_df.head()
# Out:
#                  Player  Year  Pick Team                   College
# 4545  Joe Barry Carroll  1980     1  GSW         Purdue University
# 4546   Darrell Griffith  1980     2  UTA  University of Louisville
# 4547       Kevin McHale  1980     3  BOS   University of Minnesota
# 4548      Kelvin Ransey  1980     4  CHI     Ohio State University
# 4549          James Ray  1980     5  DEN   Jacksonville University

# %%
# Create Unique Identifier Field - Concatination of Name and Draft Year
# Converted to All Upper Case, All Punctuation and Spaces Stripped
draft_df['GUID'] = draft_df['Player'] + draft_df['Year'].astype(str)

# Strip out Single Quote/Apostrophe Characters, Commas, and Periods
draft_df['GUID'] = draft_df['GUID'].str.replace(r'[^\w\s]+', '')

# Strip out spaces
draft_df['GUID'].replace('\s+', '', regex=True,inplace=True)


#rookies_df['GUID'] = rookies_df['GUID'].astype(str)
#rookies_df['GUID'].to_string()

#Convert to Upper Case
draft_df['GUID'] = draft_df['GUID'].str.upper()

draft_df.head(100)
# Out:
# C:\Users\18177\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#                  Player  Year  Pick Team                    College  \
# 4545  Joe Barry Carroll  1980     1  GSW          Purdue University
# 4546   Darrell Griffith  1980     2  UTA   University of Louisville
# 4547       Kevin McHale  1980     3  BOS    University of Minnesota
# 4548      Kelvin Ransey  1980     4  CHI      Ohio State University
# 4549          James Ray  1980     5  DEN    Jacksonville University
# ...                 ...   ...   ...  ...                        ...
# 4640      Mike Campbell  1980    96  CHI    Northwestern University
# 4641      James Patrick  1980    97  DEN     Texas State University
# 4642        Aaron Curry  1980    98  NJN     University of Oklahoma
# 4643         Wally Rank  1980    99  SDC  San Jose State University
# 4644         Joe Galvin  1980   100  IND  Illinois State University
#
#                      GUID
# 4545  JOEBARRYCARROLL1980
# 4546  DARRELLGRIFFITH1980
# 4547      KEVINMCHALE1980
# 4548     KELVINRANSEY1980
# 4549         JAMESRAY1980
# ...                   ...
# 4640     MIKECAMPBELL1980
# 4641     JAMESPATRICK1980
# 4642       AARONCURRY1980
# 4643        WALLYRANK1980
# 4644        JOEGALVIN1980
#
# [100 rows x 6 columns]

# %%
# Set new index and drop existing index
draft_df.set_index('GUID')
# Out:
#                                        Player  Year  Pick Team  \
# GUID
# JOEBARRYCARROLL1980         Joe Barry Carroll  1980     1  GSW
# DARRELLGRIFFITH1980          Darrell Griffith  1980     2  UTA
# KEVINMCHALE1980                  Kevin McHale  1980     3  BOS
# KELVINRANSEY1980                Kelvin Ransey  1980     4  CHI
# JAMESRAY1980                        James Ray  1980     5  DEN
# ...                                       ...   ...   ...  ...
# RAYSPALDING2018                  Ray Spalding  2018    56  PHI
# KEVINHERVEY2018                  Kevin Hervey  2018    57  OKC
# THOMASWELSH2018                  Thomas Welsh  2018    58  DEN
# GEORGEKING2018                    George King  2018    59  PHO
# KOSTASANTETOKOUNMPO2018  Kostas Antetokounmpo  2018    60  PHI
#
#                                                        College
# GUID
# JOEBARRYCARROLL1980                          Purdue University
# DARRELLGRIFFITH1980                   University of Louisville
# KEVINMCHALE1980                        University of Minnesota
# KELVINRANSEY1980                         Ohio State University
# JAMESRAY1980                           Jacksonville University
# ...                                                        ...
# RAYSPALDING2018                       University of Louisville
# KEVINHERVEY2018               University of Texas at Arlington
# THOMASWELSH2018          University of California, Los Angeles
# GEORGEKING2018                          University of Colorado
# KOSTASANTETOKOUNMPO2018                   University of Dayton
#
# [3418 rows x 5 columns]

# %%
# Export to CSV
#export_path = "Resources/draft_position.csv"
#draft_df.to_csv(export_path)

# %%
# import the necessary packages
import psycopg2
from sqlalchemy import create_engine
  
# Create the engine to connect to the database 
engine = create_engine(
    'postgresql+psycopg2://postgres:tC1sfkNBaUqSH4noRcz6@nba-hof-project.cxpeww6dbftb.us-east-2.rds.amazonaws.com:5432/postgres')

# Write data into the table in database
draft_df.to_sql('new_draft', engine)
